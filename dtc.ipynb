# %% [markdown]
# # psuedo code for my site

# %%
#importing lib
import pandas as pd
import mysql as ms

# %%
#reading csv file with pandas
x=pd.read_excel("fare.xlsx")

# %%
#removing first two unnecessary rows from dataframe
d=x[2::]
d
# Out:
#     Fare Stages         Unnamed: 1                     Unnamed: 2  \
# 2             1                  8               Badar Pur Border
# 3             2                 8A           Nehru Place Terminal
# 4             3                 17         Old Delhi Rly. Station
# 5             4                 19        Nizamuddin Rly. Station
# 6             5                19A                  Palika Kendra
# 7             6                19B                    Jama Masjid
# 8             7                 26       Dr.Mukherjee Nagar Bandh
# 9             8                 33                    Bhajan Pura
# 10            9                33C                  Chauhan Patti
# 11           10                 34              Mehrauli Terminal
# 12           11                34A            Lado Sarai Terminal
# 13           12                 39                          Jheel
# 14           13                39A               Anand Vihar ISBT
# 15           14                47A             Inder Puri JJ Cly.
# 16           15                 73               Anand Vihar ISBT
# 17           16                 78              Azad pur Terminal
# 18           17                 85               Anand Vihar ISBT
# 19           18              85EXT               Anand Vihar ISBT
# 20           19                 88            ISBT Nityanand Marg
# 21           20             100EXT              Kendriya Terminal
# 22           21               100A              Kendriya Terminal
# 23           22                103         Old Delhi Rly. Station
# 24           23                105  ISBT (Maharana Pratap Bus (T)
# 25           24                106         Old Delhi Rly. Station
# 26           25               106A         Old Delhi Rly. Station
# 27           26                107         Old Delhi Rly. Station
# 28           27                108                    Nehru Vihar
# 29           28                109              Azad pur Terminal
# 30           29                112         Old Delhi Rly. Station
# 31           30                113         Old Delhi Rly. Station
# ..          ...                ...                            ...
# 416         415            0118 NS                  Mori Gate (T)
# 417         416            0131 NS         Old Delhi Rly. Station
# 418         417            0205 NS         Old Delhi Rly. Station
# 419         418            0261 NS         Sarai Kale Khan (ISBT)
# 420         419            0405 NS                  Mori Gate (T)
# 421         420            0419 NS         Old Delhi Rly. Station
# 422         421            0502 NS         Old Delhi Rly. Station
# 423         422           0543A NS               Anand Vihar ISBT
# 424         423            0578 NS         Sarai Kale Khan (ISBT)
# 425         424            0604 NS   N.D. Rly. Station Gate No.-2
# 426         425            0729 NS                  Mori Gate (T)
# 427         426            0740 NS               Anand vihar ISBT
# 428         427            0753 NS                  Mori Gate (T)
# 429         428             0901NS   N.D. Rly. Station Gate No.-2
# 430         429            0926 NS         Old Delhi Rly. Station
# 431         430             0929NS         Old Delhi Rly. Station
# 432         431            0943 NS               Anand Vihar ISBT
# 433         432           0GL-23NS               Anand Vihar ISBT
# 434         433  0OMS  (+) (-)  NS           Uttam Nagar Terminal
# 435         434           0TMS+ NS                   Punjabi Bagh
# 436         435           0TMS- NS                      Wazir Pur
# 437         436   0 Airoport Exp-4  ISBT (Maharana Pratap Bus (T)
# 438         437                NCR                       Nanaksar
# 439         438                NCR                         Narela
# 440         439                NCR           Uttam Nagar Terminal
# 441         440                NCR                 Karol Bagh (T)
# 442         441                NCR                      Badar Pur
# 443         442                NCR               Anand Vihar ISBT
# 444         443                NCR   N.D. Rly. Station Gate No.-2
# 445         444                NCR            Karam Pura Terminal
#
#                                     Unnamed: 3  \
# 2                   Noida Phase-II Phool Mandi
# 3                   Noida Phase-II Phool Mandi
# 4                           Ramjan Pur Village
# 5                         Jahangir Puri E-Blk.
# 6                         Jahangir Puri E-Blk.
# 7                         Jahangir Puri E-Blk.
# 8                      Sewa Nagar Railway Xing
# 9    Noida Sector-43 (Police Chowki Sadar Pur)
# 10                            Anand Vihar ISBT
# 11                                Noida Sec-32
# 12         Mayur Vihar Phase-III, Paper Market
# 13      Tri Nagar Jai Mata Mkt. / Anand Parvat
# 14                     Tri Nagar Jai Mata Mkt.
# 15                     C.W.Shop -II / Tehkhand
# 16      Tilak Nagar / H.N.S. Pawan Sahni Chowk
# 17                      Inder Puri Krishi Kunj
# 18                            Punjabi Bagh (T)
# 19                                West Enclave
# 20          Tri Nagar Jai Mata Market Terminal
# 21                                   Samey Pur
# 22                          Badli Rly. Station
# 23                             Narela Terminal
# 24                                 Mukhmel Pur
# 25                                   Qutabgarh
# 26                                      Bawana
# 27                            Katewara Village
# 28                    H.N.S. Pawan Sahni Chowk
# 29                             Bankner Village
# 30                           Shaffiabad Border
# 31                             Sannoth Village
# ..                                         ...
# 416        Mayur Vihar Phase-III, Paper Market
# 417                                     Narela
# 418          New Seema Puri / Anand Vihar ISBT
# 419                        Nand Nagri Terminal
# 420                           Badar Pur Border
# 421                           Ambedkar Ngr (T)
# 422                                   Mehrauli
# 423                           Kapashera Border
# 424                        DICHAON KALAN DEPOT
# 425                    Chhatter Pur M. Station
# 426                           Kapashera Border
# 427                            Uttam Nagar (T)
# 428                            Uttam Nagar (T)
# 429                     Rohini Sec-22 Terminal
# 430                               Tikri Border
# 431                            Mubarkpur Dabas
# 432                       Sultan Puri Terminal
# 433              ISBT (Maharana Pratap Bus (T)
# 434                       Uttam Nagar Terminal
# 435                               Punjabi Bagh
# 436                                  Wazir Pur
# 437                   IGI Airport Terminal - 3
# 438                                  Ghaziabad
# 439                              Bahadhur Garh
# 440                                    Gurgaon
# 441                                    Gurgaon
# 442                                    Gurgaon
# 443                                    Gurgaon
# 444                              Bahadhur Garh
# 445                              Bahadhur Garh
#
#                                             Unnamed: 4  \
# 2    1. BADAR PUR  BORDER 2. BADAR PUR 3. ALI VILLA...
# 3    1. NEHRU PLACE TERMINAL 2. PUNJ SONS 3. CROWN ...
# 4    1 OLD DELHI RAILWAY STATION 2. TIS HAZARI ANIM...
# 5    1. NIZAMUDDIN RAILWAY STATION 2. P.S. NIZAMUDD...
# 6    1. PALIKA  KENDRA 2. ND RAILWAY STATION GATE-I...
# 7    1. JAMA MASJID 2. DELHI GATE 3. AJMERI GATE 4....
# 8    1. DR.MUKHERJEE NAGAR BANDH 2. GTB NAGAR (HAKI...
# 9    1. BHAJAN PURA 2. C-4 YAMUNA VIHAR 3. BABAR PU...
# 10   1. CHAUHAN PATTI 2. SONIA VIHAR E-BLOCK 3. NAN...
# 11   1. MEHRAULI 2. LADO SARAI 3. SHED -UL ZAIB 4. ...
# 12   1. LADO SARAI 2. SHAID-UL-AZAB 3. A.N.DEPOT 4....
# 13   1. JHEEL 2.Khureji Khas 3. SHAKKAR PUR 4. Rain...
# 14   1. ANAND VIHAR ISBT 2. YOJNA VIHAR 3.HARGOVIND...
# 15   1. INDER PURI JJCOLONY. 2. LOHA MANDI 3. W.P. ...
# 16   1. ANAND VIHAR ISBT 2. HP DEPOT 3. SHAKER PUR ...
# 17   1. AZAD PUR TERML. 2. ASHOK VIHAR CROSSING 3. ...
# 18   1. ANAND VIHAR ISBT 2. H.P.DEPOT 3. BALCO APPT...
# 19   1. ANAND VIHAR ISBT 2. H.P. DEPOT 3. BALCO APA...
# 20   7. ISBT NITYANAND MARG 8. ICE FACTORY 9. CLOCK...
# 21   1. KENDRIYA TERMINAL 2. RAM MANOHAR LOHIA HOSP...
# 22   1. KENDRIYA TERMINAL 2. R.M.L.H 3. REGAL 4. CH...
# 23   1. Old Delhi RAILWAY STATION  2. ISBT/ MORI GA...
# 24   1. ISBT 2. OLD SECTT 3. GTB NAGAR 4. NIRANKARI...
# 25   1.Old Delhi RAILWAY STATION  2. TIS HAZARI (An...
# 26   1.Old Delhi RAILWAY STATION  2. TIS HAZARI (An...
# 27   1. Old Delhi RAILWAY STATION 2. MORI GATE/ISBT...
# 28   1. NEHRU VIHAR 2.  BR HOSP. 3. KHALSA COLL. 4....
# 29   1. AZAD PUR TERMINAL 2. ADARSH NAGAR 3. GTK DE...
# 30   1. Old Delhi RAILWAY STATION  2. ISBT/MORI GAT...
# 31   1. Old Delhi RAILWAY STATION  2.ISBT KASHMERE ...
# ..                                                 ...
# 416  1. MORI GATE 2. RED FORT 3. DELHI GATE 4. ITO ...
# 417  1. Old Delhi RAILWAY Station 2. MORI GATE/ISBT...
# 418  1.O.D.RLY STATION  2. ISBT / MORI GATE  3. SHY...
# 419  1.SARAI KALE KHAN (ISBT) 2. ROAD BRIDGE 3. RAI...
# 420  1.MORI GATE 2. RED FORT 3. DELHI GATE 4. SUPRE...
# 421  1. Old Delhi RAILWAYSTN 2. RED FORT 3. DELHI G...
# 422  1. Old Delhi RLY STN 2.  RED FORT 3.  DELHI GA...
# 423  1. ANAND VIHAR ISBT 2. NHW CROSSING 3. VINOD N...
# 424  1. SARAI KALE KHAN  ISBT 2.MAHARANI BAGH 3.S.N...
# 425  1. N.D. RLY STN GATE NO-2. 2. PALIKA KENDRIYA ...
# 426  1. MORI GATE 2. RED FORT 3. DELHI GATE 4. VIVE...
# 427  1. ANAND VIHAR ISBT 2. HASAN PUR DEPOT (PPG) 3...
# 428  1. MORI GATE TERMINAL 2. RED FORT 3. DELHI GAT...
# 429  1. N.D. Rly. Station Gate No-2  2. DELHI GATE ...
# 430  1. OLD DELHI RAILWAY STATION  2. I SBT KASHMER...
# 431  1. Old Delhi RAILWAY Station 2. TIS HAZARI (An...
# 432  1 ANAND VIHAR ISBT 2. HASAN PUR DEPOT 3.  SHAK...
# 433  1. ISBT  2. SHAYAM GIRI MANDIR 3. SEELAM PUR  ...
# 434  1. UTTAM NAGAR. 2.DISTT. CENTER  3. MBS NAGAR....
# 435  1.PUNJABI BAGH TERMINAL 2.. WP DEPOT 3 ASHOK V...
# 436  1.WAZIR PUR DEPOT 2. PUNJABI BAGH 3. PUNJABI B...
# 437  1.ISBT 2.  RED FORT 3. DELHI GATE 4. N.D.RLY S...
# 438  1.NANAKSAR 2.BHAJAN PURA 3. LR X-ING 4.UP BDR ...
# 439  1. NARELA 2. SANNOTH/GHOGHA X-ING 3. BAWANA4.P...
# 440  1.UTTAM NAGAR 2.C-1 JANAK PURI 3.DABRI X-ING 4...
# 441  1.KAROL BAGH 2.DHAULA KUAN 3.PALAM X-ING 4.HAR...
# 442  1. BADAR PUR 2.KHANPUR 3.AHINSA SATHL 4.ANDHER...
# 443  1. ANAND VIHAR 2.NH-24 3.PUSHTA X-ING 4.SKKHAN...
# 444  1.NDRLY.STN. 2.PS PAHAR GANJ 3.DBGUPTA MKT 4.S...
# 445  1. KARAM PURA 2.PUNJABI BAGH 3.PEERA GARHI 4. ...
#
#                                             Unnamed: 5
# 2              Down Direction via same as Up Direction
# 3              Down Direction via same as Up Direction
# 4              Down Direction via same as Up Direction
# 5              Down Direction via same as Up Direction
# 6              Down Direction via same as Up Direction
# 7              Down Direction via same as Up Direction
# 8              Down Direction via same as Up Direction
# 9    25. NOIDA SECTOR-43  24.  NOIDA SEC-37.(POLICE...
# 10             Down Direction via same as Up Direction
# 11   25.  NOIDA SEC-32. 24. SEC-53 CHOWK  23. SEC-2...
# 12   25. MAYUR VIHAR PH-3, PAPER MARKET   24. MAYUR...
# 13             Down Direction via same as Up Direction
# 14   15. TRI NAGAR JAI MATA MARKET. 14. B-3 KESHAV ...
# 15             Down Direction via same as Up Direction
# 16             Down Direction via same as Up Direction
# 17             Down Direction via same as Up Direction
# 18             Down Direction via same as Up Direction
# 19             Down Direction via same as Up Direction
# 20             Down Direction via same as Up Direction
# 21             Down Direction via same as Up Direction
# 22             Down Direction via same as Up Direction
# 23   18. Narela Terminal 17. A-9 Narela 16. S.R. Ha...
# 24             Down Direction via same as Up Direction
# 25             Down Direction via same as Up Direction
# 26   18. BAWANA  17. DHAKE WALA   16. POOTH KHURD  ...
# 27             Down Direction via same as Up Direction
# 28             Down Direction via same as Up Direction
# 29   15. BANKNER VILLAGE 14 .NARELA  13. A-9 Narela...
# 30   19. SAFIABAD BDR. 18. SHAFIABAD CROSSING  17. ...
# 31             Down Direction via same as Up Direction
# ..                                                 ...
# 416            Down Direction via same as Up Direction
# 417            Down Direction via same as Up Direction
# 418            Down Direction via same as Up Direction
# 419            Down Direction via same as Up Direction
# 420            Down Direction via same as Up Direction
# 421            Down Direction via same as Up Direction
# 422            Down Direction via same as Up Direction
# 423            Down Direction via same as Up Direction
# 424  25.DKD 24. NAJAFGARH 23. ROSHANPURA 22.JHATIKR...
# 425            Down Direction via same as Up Direction
# 426            Down Direction via same as Up Direction
# 427            Down Direction via same as Up Direction
# 428            Down Direction via same as Up Direction
# 429            Down Direction via same as Up Direction
# 430            Down Direction via same as Up Direction
# 431            Down Direction via same as Up Direction
# 432            Down Direction via same as Up Direction
# 433            Down Direction via same as Up Direction
# 434            Down Direction via same as Up Direction
# 435            Down Direction via same as Up Direction
# 436            Down Direction via same as Up Direction
# 437            Down Direction via same as Up Direction
# 438            Down Direction via same as Up Direction
# 439            Down Direction via same as Up Direction
# 440            Down Direction via same as Up Direction
# 441            Down Direction via same as Up Direction
# 442            Down Direction via same as Up Direction
# 443            Down Direction via same as Up Direction
# 444            Down Direction via same as Up Direction
# 445            Down Direction via same as Up Direction
#
# [444 rows x 6 columns]

# %%
#appending different stops in list
l=[]
for i in range(2,len(d["Unnamed: 4"])):
    s=list(map(str,str(d["Unnamed: 4"][i]).split(".")))
    s.pop(0)
    l.append(s)

# %%
print(len(d["Unnamed: 4"][324]))
# Out:
# 241

# %%
#sql connector
import mysql.connector

# %%
#connecting to mysql port
mydb = mysql.connector.connect(user="joe",host='localhost', port='3306',database='test')
print(mydb)
#cursor to database
cur = mydb.cursor()
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x000002E999029B38>

# %%
#executing create table query
cur.execute("CREATE TABLE dtcdata (Bus_No VARCHAR(255), START VARCHAR(255), DEST VARCHAR(255), route VARCHAR(600))")

# %%
#inserting col in dtcdata database
sql = "INSERT INTO dtcdata (Bus_No, START, DEST, Route) VALUES (%s, %s, %s, %s)"

# %%
#appending colums tupe to list
val=[]
for i in range(2,len(d["Unnamed: 1"])):
    val.append((str(d["Unnamed: 1"][i]),str(d["Unnamed: 2"][i]),str(d["Unnamed: 3"][i]),str(d["Unnamed: 4"][i])))

# %%
#inserting sql values to cur 
cur.executemany(sql, val)

# %%
#finilizing database
mydb.commit()

# %%
print(cur.rowcount, "was inserted.")
# Out:
# 442 was inserted.

# %%
cur.execute("SELECT * FROM dtcdata")
#storing database to var
records = cur.fetchall()

# %%
print((records[448]))
# Out:
# ('26', 'Dr.Mukherjee Nagar Bandh', 'Sewa Nagar Railway Xing', '1. DR.MUKHERJEE NAGAR BANDH 2. GTB NAGAR (HAKIKAT NAGAR)  3 OLD SECTT. 4. ISBT KASHMERE GATE  5. RED FORT 6. DELHI GATE 7. SUPREME COURT 8. SHAHJAHAN RD 9. BHARTI NAGAR 10. LODHI COLONY 11. SEWA NAGAR RLY CROSSING.')

# %%
#simple code to get data
def getres(records, bus_no, opt):
    if opt>=1 and opt<=3:
        for i in range(len(records)):
            if records[i][0] == bus_no:
                print(records[i][opt])
                break

# %%
getres(records, "26", 2)
# Out:
# Sewa Nagar Railway Xing
